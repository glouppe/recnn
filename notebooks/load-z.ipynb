# %%
import ast
import numpy as np
import re
import glob 
import pickle

# %%
pattern_new_jet = r"""NEWJET: ([-+]?\d*\.\d+([Ee][-+]?\d+)?|[-+]?\d+) ([-+]?\d*\.\d+([Ee][-+]?\d+)?|[-+]?\d+) ([-+]?\d*\.\d+([Ee][-+]?\d+)?|[-+]?\d+) ([-+]?\d*\.\d+([Ee][-+]?\d+)?|[-+]?\d+) ([-+]?\d*\.\d+([Ee][-+]?\d+)?|[-+]?\d+) ([-+]?\d*\.\d+([Ee][-+]?\d+)?|[-+]?\d+) ([-+]?\d*\.\d+([Ee][-+]?\d+)?|[-+]?\d+) ([-+]?\d*\.\d+([Ee][-+]?\d+)?|[-+]?\d+) ([-+]?\d*\.\d+([Ee][-+]?\d+)?|[-+]?\d+) (.*) (Z\:([01]))"""
pattern_jet_tree = r"""JETHISTORYTREE: (.*)"""
pattern_jet_tree_content = r"""JETHISTORYCONTENT: (.*)"""

def load_from_text(filename, take="first"):
    with open(filename, "r") as f:
        jets = []
        skip_rest = True
        
        for i, line in enumerate(f):
            if line.startswith("NEWEVENT"):
                skip_rest = False
            
            elif line.startswith("NEWJET"):
                jet = {}
                try:
                    m = re.match(pattern_new_jet, line).groups()
                    jet["root_id"] = int(m[0])
                    jet["radius"] = float(m[2])
                    jet["pt"] = float(m[4])
                    jet["eta"] = float(m[6])
                    jet["phi"] = float(m[8])
                    jet["energy"] = float(m[10])
                    jet["tau21"] = float(m[12])
                    jet["tau32"] = float(m[14])
                    jet["d2"] = float(m[16])
                    jet["z"] = int(m[20])
                except:
                    skip_rest = True
                
            elif line.startswith("JETHISTORYTREE"):
                if not skip_rest:
                    m = re.match(pattern_jet_tree, line).groups()
                    jet["tree"] = ast.literal_eval(m[0])
                
            elif line.startswith("JETHISTORYCONTENT"):
                if not skip_rest:
                    m = re.match(pattern_jet_tree_content, line).groups()
                    jet["content"] = ast.literal_eval(m[0])
                
                    if take == "first":
                        jets.append(jet)
                        skip_rest = True
                        
                    elif take == "all":
                        jets.append(jet)
                        
                    elif take == "z" and jet["z"] == 1:
                        jets.append(jet)
                        skip_rest = True
                
    for jet in jets:
        tree = np.array([jet["tree"][n] for n in sorted(jet["tree"])], dtype=np.int)
        tree[tree == -2] = -1
        content = np.array([jet["content"][n][1:5] for n in sorted(jet["content"])], dtype=np.float)
        jet["tree"] = tree
        jet["content"] = content
    
    return jets

# %%
background = []

for f in glob.glob("/home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/*.dat"):
    print(f)
    background.extend(load_from_text(f, take="first"))
    
fd = open("../data/z/kt-background.pickle", "wb")

for jet in background:
    pickle.dump(jet, fd, protocol=pickle.HIGHEST_PROTOCOL)

fd.close()
# Out:
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_43.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_37.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_40.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_15.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_29.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_2.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_14.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_38.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_46.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_32.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_3.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_21.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_30.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_27.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_34.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_1.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_13.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_48.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_45.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_23.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_31.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_50.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_44.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_4.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_7.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_47.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_24.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_19.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_49.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_12.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_33.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_11.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_35.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_36.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_8.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_26.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_17.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_42.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_39.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_22.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_25.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/background/MC15.361039.Sherpa_CT10_SinglePhoton_noPtSlice_CVetoBVeto_KT_20.dat

# %%
signal = []

for f in glob.glob("/home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/*.dat"):
    print(f)
    signal.extend(load_from_text(f, take="z"))
    
fd = open("../data/z/kt-mH700.pickle", "wb")

for jet in signal:
    pickle.dump(jet, fd, protocol=pickle.HIGHEST_PROTOCOL)

fd.close()
# Out:
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_17.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_50.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_44.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_12.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_6.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_25.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_38.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_34.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_35.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_26.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_45.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_28.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_31.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_13.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_40.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_18.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_27.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_20.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_4.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_30.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_29.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_36.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_32.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_22.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_3.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_42.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_21.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_49.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_48.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_14.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_16.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_9.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_46.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_10.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_8.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_41.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_7.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_2.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_39.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_11.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_5.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_19.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_23.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_43.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_15.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_47.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_37.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_33.dat
# /home/gilles/gdrive/research/sandbox/learning-qcd-rnn/data/z/large/KT/mH700/MC15.343581.PowhegPythia8EvtGen_CT10_AZNLOCTEQ6L1_ggH700_Zqqgam_KT_24.dat
